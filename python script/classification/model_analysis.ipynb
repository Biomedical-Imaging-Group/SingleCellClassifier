# %% [markdown]
# # Model analysis
#
# This notebook allows you to analyse your classification model and more specificaly the features importance.

# %%
import pandas as pd
import numpy as np
import tensorflow as tf
from tensorflow import keras
from helpers import *
# Out:
# D:\Anaconda3\envs\ProjetSemestre\lib\site-packages\tensorflow\python\framework\dtypes.py:526: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# D:\Anaconda3\envs\ProjetSemestre\lib\site-packages\tensorflow\python\framework\dtypes.py:527: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# D:\Anaconda3\envs\ProjetSemestre\lib\site-packages\tensorflow\python\framework\dtypes.py:528: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# D:\Anaconda3\envs\ProjetSemestre\lib\site-packages\tensorflow\python\framework\dtypes.py:529: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# D:\Anaconda3\envs\ProjetSemestre\lib\site-packages\tensorflow\python\framework\dtypes.py:530: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# D:\Anaconda3\envs\ProjetSemestre\lib\site-packages\tensorflow\python\framework\dtypes.py:535: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])
# Using TensorFlow backend.

# %% [markdown]
# ## Data loading
#
# The loading is designed for csv file generated by the Collect Information option of the ImageJ plugin. The class of the nuclei is missing must be indicated (classes mask option).
#
# [TODO] write the path of your measurements files, create your dataset and write the possible classes

# %%
mouse_path = "../../data/measurements/mouse features.csv"
human_path = "../../data/measurements/human features.csv"
human_tumor_path = "../../data/measurements/human tumor features.csv"

mouse = get_data(mouse_path, "Mouse")
human = get_data(human_path, "Human")
human_tumor = get_data(human_tumor_path, "Human")

dataset = pd.concat([mouse, human, human_tumor], ignore_index=True)

classes = ["Mouse", "Human"]

# %%
dataset[CLASS_COLUMN].value_counts()
# Out:
# Human    47529
# Mouse    41511
# Name: Class, dtype: int64

# %% [markdown]
# ## Data processing
# Shuffle, normalize and split the data between inputs and targets.

# %%
inputs, targets = process_prediction_data(dataset, classes, 'models/classification/normalization.json', True)

# %% [markdown]
# CSBDeep need 3D images with more than 1 element in each dimension, we create an image of size (2, 2, feature_size / 4). If the feature size is not a multiple of 4, it will be padded with 0. As we remove the reshape layer, we put back its size to feature_size (still a multiple of 4).

# %%
num_features = inputs.shape[1]
input_size = int(np.ceil(num_features/4) * 4)

inputs = resize_inputs(inputs).reshape((-1, input_size))

# %% [markdown]
# ## Load model
#
# [TODO] write the path of your model file

# %%
model = keras.models.load_model('models/classification/model.h5')

# remove first layer (reshape) as it created for CSBDeep and is not compatible with analysis
model_copy = get_model(input_size, len(classes), False)

for i, layer in enumerate(model.layers[1:]):
    model_copy.layers[i].set_weights(layer.get_weights())

optimizer = keras.optimizers.Adam()
loss_function = 'categorical_crossentropy'

model_copy.compile(optimizer=optimizer, loss=loss_function, metrics=['accuracy'])

model_copy.summary()
# Out:
# WARNING:tensorflow:From D:\Anaconda3\envs\ProjetSemestre\lib\site-packages\tensorflow\python\ops\resource_variable_ops.py:435: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# WARNING:tensorflow:From D:\Anaconda3\envs\ProjetSemestre\lib\site-packages\tensorflow\python\keras\layers\core.py:143: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.
# WARNING:tensorflow:From D:\Anaconda3\envs\ProjetSemestre\lib\site-packages\tensorflow\python\ops\math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 128)               62080
# _________________________________________________________________
# batch_normalization_v1 (Batc (None, 128)               512
# _________________________________________________________________
# re_lu (ReLU)                 (None, 128)               0
# _________________________________________________________________
# dropout (Dropout)            (None, 128)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 64)                8256
# _________________________________________________________________
# batch_normalization_v1_1 (Ba (None, 64)                256
# _________________________________________________________________
# re_lu_1 (ReLU)               (None, 64)                0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 64)                0
# _________________________________________________________________
# dense_2 (Dense)              (None, 32)                2080
# _________________________________________________________________
# batch_normalization_v1_2 (Ba (None, 32)                128
# _________________________________________________________________
# re_lu_2 (ReLU)               (None, 32)                0
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 32)                0
# _________________________________________________________________
# dense_3 (Dense)              (None, 16)                528
# _________________________________________________________________
# batch_normalization_v1_3 (Ba (None, 16)                64
# _________________________________________________________________
# re_lu_3 (ReLU)               (None, 16)                0
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 16)                0
# _________________________________________________________________
# dense_4 (Dense)              (None, 2)                 34
# _________________________________________________________________
# activation (Activation)      (None, 2)                 0
# =================================================================
# Total params: 73,938
# Trainable params: 73,458
# Non-trainable params: 480
# _________________________________________________________________

# %% [markdown]
# ## Analyse features importance

# %%
import eli5
from eli5.permutation_importance import get_score_importances

nb_observation = 500
inputs_obs = inputs[:nb_observation,:]
targets_obs = targets[:nb_observation,:]

def score(x, y):
    loss, accuracy = model_copy.evaluate(x, y, verbose=0)
    return accuracy

base_score, score_decreases = get_score_importances(score, inputs_obs, targets_obs, n_iter=10)
feature_importances = np.mean(score_decreases, axis=0)
feature_std = np.std(score_decreases, axis=0)

headers = dataset.columns.values

sort_index = np.argsort(feature_importances)[::-1]
print("Feature Importances:")
for i in range(input_size):
    j = sort_index[i]
    if(j < num_features):
        print(headers[j + 1] +":  "+ str(np.round(feature_importances[j],3)) + " +- " + str(np.round(feature_std[j],3)))
# Out:
# D:\Anaconda3\envs\ProjetSemestre\lib\site-packages\sklearn\utils\deprecation.py:144: FutureWarning: The sklearn.metrics.scorer module is  deprecated in version 0.22 and will be removed in version 0.24. The corresponding classes / functions should instead be imported from sklearn.metrics. Anything that cannot be imported from sklearn.metrics is now part of the private API.
#   warnings.warn(message, FutureWarning)
# D:\Anaconda3\envs\ProjetSemestre\lib\site-packages\sklearn\utils\deprecation.py:144: FutureWarning: The sklearn.feature_selection.base module is  deprecated in version 0.22 and will be removed in version 0.24. The corresponding classes / functions should instead be imported from sklearn.feature_selection. Anything that cannot be imported from sklearn.feature_selection is now part of the private API.
#   warnings.warn(message, FutureWarning)
# Feature Importances:
# Mean cytoplasm variance value channel 1 up to 40 connected neighbours:  0.078 +- 0.011
# Cytoplasm variance value channel 1:  0.025 +- 0.003
# Mean cytoplasm sum of squares: variance up to 40 connected neighbours:  0.025 +- 0.005
# Mean cytoplasm variance value channel 2 up to 40 connected neighbours:  0.023 +- 0.004
# Cytoplasm mean value channel 1:  0.017 +- 0.005
# Mean cytoplasm variance value channel 1 up to 20 connected neighbours:  0.017 +- 0.005
# Mean cytoplasm variance value channel 3 up to 20 connected neighbours:  0.015 +- 0.005
# Nucleus mean value channel 1:  0.014 +- 0.006
# Mean cytoplasm difference variance up to 40 connected neighbours:  0.013 +- 0.003
# Mean cytoplasm variance value channel 1 up to 5 connected neighbours:  0.013 +- 0.005
# Mean cytoplasm variance value channel 1 up to 10 connected neighbours:  0.012 +- 0.005
# Mean cytoplasm correlation up to 40 connected neighbours:  0.012 +- 0.004
# Mean nucleus correlation up to 20 connected neighbours:  0.008 +- 0.003
# Cytoplasm mean value channel 3:  0.008 +- 0.003
# Variance area ratio up to 40 connected neighbours:  0.008 +- 0.002
# Mean cytoplasm variance value channel 3 up to 10 connected neighbours:  0.008 +- 0.005
# Mean cytoplasm variance value channel 3 up to 5 connected neighbours:  0.007 +- 0.003
# Nucleus mean value channel 3:  0.007 +- 0.003
# Mean cytoplasm difference variance up to 20 connected neighbours:  0.007 +- 0.002
# Mean cytoplasm correlation up to 20 connected neighbours:  0.007 +- 0.003
# Mean nucleus variance value channel 1 up to 5 connected neighbours:  0.007 +- 0.002
# Mean nucleus correlation up to 40 connected neighbours:  0.007 +- 0.003
# Variance nucleus area up to 40 connected neighbours:  0.007 +- 0.002
# Variance cell elongation up to 40 connected neighbours:  0.006 +- 0.005
# Mean nucleus inverse difference moment up to 40 connected neighbours:  0.006 +- 0.002
# Mean area ratio up to 5 connected neighbours:  0.006 +- 0.002
# Mean cytoplasm contrast up to 40 connected neighbours:  0.006 +- 0.003
# Distance to centroid up to 40 neighbours:  0.006 +- 0.004
# Nucleus correlation:  0.006 +- 0.004
# Mean nucleus difference variance up to 40 connected neighbours:  0.005 +- 0.003
# Variance area ratio up to 20 connected neighbours:  0.005 +- 0.001
# Mean nucleus variance value channel 3 up to 40 connected neighbours:  0.005 +- 0.003
# Mean nucleus variance value channel 3 up to 20 connected neighbours:  0.005 +- 0.003
# Variance nucleus major axis up to 40 connected neighbours:  0.005 +- 0.002
# Mean nucleus variance value channel 2 up to 20 connected neighbours:  0.005 +- 0.002
# Mean nucleus inverse difference moment up to 5 connected neighbours:  0.005 +- 0.004
# Mean cytoplasm sum variance up to 5 connected neighbours:  0.005 +- 0.002
# Mean nucleus angular second moment up to 40 connected neighbours:  0.005 +- 0.003
# Mean nucleus variance value channel 1 up to 20 connected neighbours:  0.005 +- 0.003
# Mean nucleus sum variance up to 40 connected neighbours:  0.004 +- 0.002
# Ellipse minor axis up to 40 connected neighbours:  0.004 +- 0.002
# Variance nucleus minor axis up to 5 connected neighbours:  0.004 +- 0.002
# Nucleus difference entropy:  0.004 +- 0.003
# Nucleus elongation:  0.004 +- 0.001
# Mean nucleus mean value channel 1 up to 5 connected neighbours:  0.004 +- 0.003
# Variance nucleus elongation up to 40 connected neighbours:  0.004 +- 0.001
# Variance cell major axis up to 40 connected neighbours:  0.004 +- 0.004
# Cytoplasm correlation:  0.004 +- 0.002
# Ellipse major axis up to 40 connected neighbours:  0.004 +- 0.003
# Variance nucleus entropy up to 10 connected neighbours:  0.004 +- 0.002
# Mean nucleus variance value channel 1 up to 10 connected neighbours:  0.004 +- 0.002
# Variance cytoplasm mean value channel 2 up to 10 connected neighbours:  0.004 +- 0.003
# Variance nucleus area up to 20 connected neighbours:  0.004 +- 0.002
# Mean cytoplasm sum of squares: variance up to 20 connected neighbours:  0.004 +- 0.003
# Variance cytoplasm information measures correlation 1 up to 40 connected neighbours:  0.004 +- 0.001
# Variance cell area up to 40 connected neighbours:  0.004 +- 0.002
# Variance nucleus major axis up to 10 connected neighbours:  0.004 +- 0.001
# Nucleus sum average:  0.004 +- 0.004
# Mean cytoplasm inverse difference moment up to 20 connected neighbours:  0.004 +- 0.002
# Mean cytoplasm variance value channel 3 up to 40 connected neighbours:  0.004 +- 0.002
# Mean cytoplasm information measures correlation 1 up to 40 connected neighbours:  0.004 +- 0.003
# Mean nucleus inverse difference moment up to 20 connected neighbours:  0.004 +- 0.001
# Mean nucleus correlation up to 10 connected neighbours:  0.004 +- 0.004
# Mean nucleus variance value channel 1 up to 40 connected neighbours:  0.004 +- 0.002
# Cytoplasm information measures correlation 1:  0.004 +- 0.002
# Variance nucleus area up to 10 connected neighbours:  0.004 +- 0.002
# Mean nucleus angular second moment up to 20 connected neighbours:  0.004 +- 0.001
# Cytoplasm variance value channel 3:  0.004 +- 0.002
# Ellipse minor axis up to 20 connected neighbours:  0.004 +- 0.001
# Mean nucleus information measures correlation 1 up to 5 connected neighbours:  0.004 +- 0.002
# Mean cytoplasm inverse difference moment up to 5 connected neighbours:  0.004 +- 0.001
# Mean cytoplasm information measures correlation 1 up to 20 connected neighbours:  0.003 +- 0.002
# Cytoplasm contrast:  0.003 +- 0.001
# Mean cytoplasm angular second moment up to 20 connected neighbours:  0.003 +- 0.002
# Ellipse orientation difference up to 40 connected neighbours:  0.003 +- 0.002
# Variance nucleus minor axis up to 40 connected neighbours:  0.003 +- 0.002
# Nucleus sum variance:  0.003 +- 0.003
# Variance cell area up to 20 connected neighbours:  0.003 +- 0.002
# Mean nucleus inverse difference moment up to 10 connected neighbours:  0.003 +- 0.001
# Mean cytoplasm correlation up to 10 connected neighbours:  0.003 +- 0.002
# Variance nucleus sum entropy up to 40 connected neighbours:  0.003 +- 0.001
# Mean cytoplasm contrast up to 20 connected neighbours:  0.003 +- 0.003
# Nucleus variance value channel 1:  0.003 +- 0.003
# Mean distance up to 10 neighbours:  0.003 +- 0.003
# Ellipse major axis up to 10 connected neighbours:  0.003 +- 0.002
# Variance cell minor axis up to 20 connected neighbours:  0.003 +- 0.001
# Mean cytoplasm angular second moment up to 40 connected neighbours:  0.003 +- 0.002
# Variance cytoplasm variance value channel 2 up to 20 connected neighbours:  0.003 +- 0.001
# Variance cytoplasm entropy up to 40 connected neighbours:  0.003 +- 0.001
# Mean cytoplasm information measures correlation 1 up to 10 connected neighbours:  0.003 +- 0.002
# Variance nucleus elongation up to 10 connected neighbours:  0.003 +- 0.001
# Mean nucleus correlation up to 5 connected neighbours:  0.003 +- 0.004
# Mean nucleus variance value channel 3 up to 10 connected neighbours:  0.003 +- 0.002
# Mean nucleus information measures correlation 1 up to 40 connected neighbours:  0.003 +- 0.003
# Mean nucleus angular second moment up to 5 connected neighbours:  0.003 +- 0.002
# Mean cytoplasm variance value channel 2 up to 20 connected neighbours:  0.003 +- 0.001
# Lateral neighbours orientation differences:  0.003 +- 0.001
# Cytoplasm sum average:  0.003 +- 0.002
# Cytoplasm sum variance:  0.003 +- 0.003
# Mean nucleus information measures correlation 1 up to 20 connected neighbours:  0.003 +- 0.002
# Mean nucleus variance value channel 3 up to 5 connected neighbours:  0.003 +- 0.002
# Variance nucleus correlation up to 5 connected neighbours:  0.003 +- 0.002
# Ellipse minor axis up to 5 connected neighbours:  0.003 +- 0.002
# Variance distance up to 10 connected neighbours:  0.003 +- 0.002
# Mean cytoplasm mean value channel 1 up to 40 connected neighbours:  0.003 +- 0.002
# Mean nucleus area up to 5 connected neighbours:  0.003 +- 0.002
# Ellipse elongation up to 40 connected neighbours:  0.003 +- 0.002
# Mean nucleus elongation up to 20 connected neighbours:  0.003 +- 0.002
# Variance cytoplasm sum of squares: variance up to 40 connected neighbours:  0.003 +- 0.001
# Mean nucleus contrast up to 40 connected neighbours:  0.003 +- 0.003
# Mean cell major axis up to 40 connected neighbours:  0.003 +- 0.003
# Mean nucleus minor axis up to 5 connected neighbours:  0.003 +- 0.002
# Ellipse variance orientation difference up to 10 connected neighbours:  0.003 +- 0.002
# Variance orientation difference up to 20 connected neighbours:  0.003 +- 0.002
# Variance nucleus difference entropy up to 5 connected neighbours:  0.003 +- 0.002
# Mean nucleus mean value channel 2 up to 5 connected neighbours:  0.003 +- 0.002
# Variance cell area up to 5 connected neighbours:  0.003 +- 0.001
# Variance nucleus difference variance up to 5 connected neighbours:  0.003 +- 0.001
# Cells chain non reciprocal neighbours:  0.003 +- 0.001
# Variance cytoplasm difference variance up to 40 connected neighbours:  0.003 +- 0.001
# Mean orientation difference up to 5 connected neighbours:  0.003 +- 0.002
# Mean cytoplasm sum of squares: variance up to 10 connected neighbours:  0.003 +- 0.003
# Variance nucleus correlation up to 20 connected neighbours:  0.002 +- 0.001
# Mean nucleus difference variance up to 20 connected neighbours:  0.002 +- 0.002
# Mean distance up to 40 connected neighbours:  0.002 +- 0.002
# Variance nucleus inverse difference moment up to 10 connected neighbours:  0.002 +- 0.001
# Mean cytoplasm difference entropy up to 5 connected neighbours:  0.002 +- 0.001
# Mean nucleus area up to 40 connected neighbours:  0.002 +- 0.002
# Mean cytoplasm mean value channel 2 up to 40 connected neighbours:  0.002 +- 0.002
# Variance nucleus variance value channel 1 up to 5 connected neighbours:  0.002 +- 0.001
# Variance nucleus angular second moment up to 40 connected neighbours:  0.002 +- 0.001
# Variance cell minor axis up to 10 connected neighbours:  0.002 +- 0.002
# Mean nucleus sum variance up to 5 connected neighbours:  0.002 +- 0.002
# Variance nucleus minor axis up to 20 connected neighbours:  0.002 +- 0.002
# Mean cytoplasm mean value channel 1 up to 20 connected neighbours:  0.002 +- 0.002
# Mean cell elongation up to 40 connected neighbours:  0.002 +- 0.002
# Mean area ratio up to 40 connected neighbours:  0.002 +- 0.003
# Variance nucleus information measures correlation 1 up to 5 connected neighbours:  0.002 +- 0.001
# Mean cytoplasm variance value channel 2 up to 5 connected neighbours:  0.002 +- 0.002
# Mean nucleus information measures correlation 2 up to 40 connected neighbours:  0.002 +- 0.001
# Variance cytoplasm mean value channel 3 up to 10 connected neighbours:  0.002 +- 0.002
# Mean cytoplasm variance value channel 2 up to 10 connected neighbours:  0.002 +- 0.002
# Variance cytoplasm mean value channel 2 up to 40 connected neighbours:  0.002 +- 0.002
# Variance nucleus minor axis up to 10 connected neighbours:  0.002 +- 0.002
# Variance area ratio up to 10 connected neighbours:  0.002 +- 0.001
# Mean cell area up to 20 connected neighbours:  0.002 +- 0.002
# Ellipse orientation difference up to 5 connected neighbours:  0.002 +- 0.001
# Nucleus minor Axis:  0.002 +- 0.002
# Cell major Axis:  0.002 +- 0.002
# Mean nucleus elongation up to 5 connected neighbours:  0.002 +- 0.001
# Variance nucleus information measures correlation 2 up to 10 connected neighbours:  0.002 +- 0.001
# Variance nucleus mean value channel 3 up to 10 connected neighbours:  0.002 +- 0.001
# Variance nucleus area up to 5 connected neighbours:  0.002 +- 0.001
# Mean nucleus sum variance up to 10 connected neighbours:  0.002 +- 0.002
# Mean nucleus sum of squares: variance up to 20 connected neighbours:  0.002 +- 0.002
# Direct neighbours mean distance:  0.002 +- 0.003
# Nucleus sum entropy:  0.002 +- 0.002
# Ellipse orientation difference up to 20 connected neighbours:  0.002 +- 0.003
# Mean nucleus difference entropy up to 40 connected neighbours:  0.002 +- 0.001
# Mean nucleus sum variance up to 20 connected neighbours:  0.002 +- 0.001
# Mean cytoplasm difference entropy up to 40 connected neighbours:  0.002 +- 0.001
# Nucleus mean value channel 2:  0.002 +- 0.001
# Ellipse orientation difference up to 10 connected neighbours:  0.002 +- 0.001
# Mean nucleus variance value channel 2 up to 5 connected neighbours:  0.002 +- 0.001
# Variance cytoplasm mean value channel 1 up to 10 connected neighbours:  0.002 +- 0.001
# Mean cytoplasm mean value channel 2 up to 5 connected neighbours:  0.002 +- 0.001
# Variance nucleus information measures correlation 2 up to 40 connected neighbours:  0.002 +- 0.001
# Variance nucleus major axis up to 5 connected neighbours:  0.002 +- 0.001
# Cytoplasm inverse difference moment:  0.002 +- 0.001
# Variance nucleus variance value channel 2 up to 5 connected neighbours:  0.002 +- 0.001
# Variance nucleus mean value channel 1 up to 5 connected neighbours:  0.002 +- 0.001
# Variance cell minor axis up to 5 connected neighbours:  0.002 +- 0.001
# Variance nucleus variance value channel 3 up to 5 connected neighbours:  0.002 +- 0.0
# Variance cytoplasm inverse difference moment up to 20 connected neighbours:  0.002 +- 0.0
# Variance nucleus mean value channel 1 up to 20 connected neighbours:  0.002 +- 0.0
# Variance nucleus elongation up to 5 connected neighbours:  0.002 +- 0.0
# Variance nucleus sum of squares: variance up to 5 connected neighbours:  0.002 +- 0.0
# Variance cell minor axis up to 40 connected neighbours:  0.002 +- 0.0
# Variance cytoplasm inverse difference moment up to 10 connected neighbours:  0.002 +- 0.0
# Mean cytoplasm difference entropy up to 10 connected neighbours:  0.002 +- 0.002
# Mean cytoplasm entropy up to 10 connected neighbours:  0.002 +- 0.002
# Mean nucleus mean value channel 3 up to 40 connected neighbours:  0.002 +- 0.002
# Nucleus difference variance:  0.002 +- 0.002
# Ellipse major axis up to 5 connected neighbours:  0.002 +- 0.002
# Variance cell elongation up to 20 connected neighbours:  0.002 +- 0.001
# Variance cytoplasm sum entropy up to 10 connected neighbours:  0.002 +- 0.001
# Mean nucleus sum average up to 5 connected neighbours:  0.002 +- 0.002
# Ellipse variance orientation difference up to 5 connected neighbours:  0.002 +- 0.001
# Mean nucleus information measures correlation 1 up to 10 connected neighbours:  0.002 +- 0.001
# Variance nucleus entropy up to 5 connected neighbours:  0.002 +- 0.002
# Variance nucleus information measures correlation 1 up to 10 connected neighbours:  0.002 +- 0.001
# Mean nucleus difference entropy up to 5 connected neighbours:  0.002 +- 0.002
# Variance cell elongation up to 5 connected neighbours:  0.002 +- 0.002
# Variance nucleus sum variance up to 5 connected neighbours:  0.002 +- 0.001
# Variance cytoplasm sum variance up to 5 connected neighbours:  0.002 +- 0.001
# Mean cytoplasm inverse difference moment up to 40 connected neighbours:  0.002 +- 0.001
# Variance cytoplasm sum variance up to 10 connected neighbours:  0.002 +- 0.002
# Variance nucleus elongation up to 20 connected neighbours:  0.002 +- 0.002
# Nucleus angular second moment:  0.002 +- 0.001
# Nucleus variance value channel 3:  0.002 +- 0.002
# Ellipse mean orientation difference up to 20 connected neighbours:  0.002 +- 0.001
# Mean distance up to 5 connected neighbours:  0.002 +- 0.002
# Cytoplasm information measures correlation 2:  0.002 +- 0.002
# Mean cytoplasm information measures correlation 1 up to 5 connected neighbours:  0.002 +- 0.003
# Nucleus major Axis:  0.002 +- 0.001
# Mean nucleus sum of squares: variance up to 10 connected neighbours:  0.002 +- 0.001
# Nucleus entropy:  0.002 +- 0.001
# Mean cytoplasm sum average up to 10 connected neighbours:  0.002 +- 0.002
# Mean distance up to 40 neighbours:  0.002 +- 0.001
# Variance nucleus inverse difference moment up to 40 connected neighbours:  0.002 +- 0.001
# Ellipse variance orientation difference up to 40 connected neighbours:  0.002 +- 0.002
# Cytoplasm mean value channel 2:  0.002 +- 0.001
# Mean cytoplasm entropy up to 40 connected neighbours:  0.002 +- 0.001
# Mean distance up to 10 connected neighbours:  0.002 +- 0.001
# Variance cytoplasm sum entropy up to 20 connected neighbours:  0.002 +- 0.001
# Mean nucleus variance value channel 2 up to 40 connected neighbours:  0.002 +- 0.001
# Variance cytoplasm correlation up to 20 connected neighbours:  0.002 +- 0.001
# Variance distance up to 20 neighbours:  0.001 +- 0.002
# Variance cytoplasm sum variance up to 40 connected neighbours:  0.001 +- 0.002
# Mean cytoplasm sum average up to 40 connected neighbours:  0.001 +- 0.002
# Mean nucleus mean value channel 1 up to 10 connected neighbours:  0.001 +- 0.002
# Mean cytoplasm sum variance up to 20 connected neighbours:  0.001 +- 0.002
# Variance cytoplasm mean value channel 3 up to 40 connected neighbours:  0.001 +- 0.002
# Mean distance up to 20 connected neighbours:  0.001 +- 0.001
# Variance nucleus information measures correlation 2 up to 5 connected neighbours:  0.001 +- 0.001
# Distance to centroid up to 10 neighbours:  0.001 +- 0.001
# Ellipse mean orientation difference up to 10 connected neighbours:  0.001 +- 0.001
# Mean nucleus major axis up to 40 connected neighbours:  0.001 +- 0.001
# Variance cell major axis up to 20 connected neighbours:  0.001 +- 0.001
# Mean nucleus sum entropy up to 20 connected neighbours:  0.001 +- 0.001
# Mean cytoplasm difference entropy up to 20 connected neighbours:  0.001 +- 0.001
# Ellipse major axis up to 20 connected neighbours:  0.001 +- 0.001
# Mean nucleus angular second moment up to 10 connected neighbours:  0.001 +- 0.001
# Variance cytoplasm entropy up to 10 connected neighbours:  0.001 +- 0.001
# Mean cytoplasm sum average up to 5 connected neighbours:  0.001 +- 0.002
# Mean distance up to 20 neighbours:  0.001 +- 0.002
# Cytoplasm variance value channel 2:  0.001 +- 0.002
# Mean cytoplasm angular second moment up to 5 connected neighbours:  0.001 +- 0.002
# Variance cell major axis up to 10 connected neighbours:  0.001 +- 0.001
# Distance to centroid up to 20 neighbours:  0.001 +- 0.001
# Variance cytoplasm correlation up to 10 connected neighbours:  0.001 +- 0.001
# Variance cytoplasm inverse difference moment up to 5 connected neighbours:  0.001 +- 0.001
# Ellipse variance orientation difference up to 20 connected neighbours:  0.001 +- 0.001
# Mean nucleus sum of squares: variance up to 40 connected neighbours:  0.001 +- 0.001
# Mean nucleus sum average up to 40 connected neighbours:  0.001 +- 0.001
# Variance orientation difference up to 10 connected neighbours:  0.001 +- 0.001
# Mean nucleus major axis up to 20 connected neighbours:  0.001 +- 0.001
# Distance to centroid up to 5 neighbours:  0.001 +- 0.001
# Mean nucleus mean value channel 2 up to 40 connected neighbours:  0.001 +- 0.001
# Cytoplasm difference variance:  0.001 +- 0.002
# Variance cytoplasm correlation up to 40 connected neighbours:  0.001 +- 0.001
# Mean cell area up to 10 connected neighbours:  0.001 +- 0.001
# Mean cytoplasm sum entropy up to 40 connected neighbours:  0.001 +- 0.001
# Mean nucleus elongation up to 10 connected neighbours:  0.001 +- 0.001
# Mean nucleus sum entropy up to 10 connected neighbours:  0.001 +- 0.001
# Mean nucleus contrast up to 20 connected neighbours:  0.001 +- 0.001
# Mean nucleus mean value channel 3 up to 20 connected neighbours:  0.001 +- 0.001
# Mean nucleus minor axis up to 40 connected neighbours:  0.001 +- 0.001
# Mean cytoplasm inverse difference moment up to 10 connected neighbours:  0.001 +- 0.001
# Variance nucleus difference entropy up to 40 connected neighbours:  0.001 +- 0.001
# Lateral neighbours mean distance:  0.001 +- 0.001
# Mean orientation difference up to 20 connected neighbours:  0.001 +- 0.001
# Variance cytoplasm contrast up to 40 connected neighbours:  0.001 +- 0.001
# Variance nucleus major axis up to 20 connected neighbours:  0.001 +- 0.001
# Mean nucleus variance value channel 2 up to 10 connected neighbours:  0.001 +- 0.001
# Variance cytoplasm difference entropy up to 40 connected neighbours:  0.001 +- 0.001
# Mean nucleus mean value channel 3 up to 5 connected neighbours:  0.001 +- 0.001
# Mean cytoplasm sum average up to 20 connected neighbours:  0.001 +- 0.001
# Mean nucleus sum entropy up to 40 connected neighbours:  0.001 +- 0.001
# Variance distance up to 20 connected neighbours:  0.001 +- 0.001
# Variance area ratio up to 5 connected neighbours:  0.001 +- 0.001
# Variance cytoplasm sum average up to 20 connected neighbours:  0.001 +- 0.001
# Mean nucleus mean value channel 1 up to 40 connected neighbours:  0.001 +- 0.001
# Variance cytoplasm variance value channel 1 up to 5 connected neighbours:  0.001 +- 0.001
# Mean cytoplasm correlation up to 5 connected neighbours:  0.001 +- 0.002
# Variance cytoplasm contrast up to 5 connected neighbours:  0.001 +- 0.002
# Variance cytoplasm mean value channel 1 up to 5 connected neighbours:  0.001 +- 0.002
# Mean cytoplasm mean value channel 1 up to 5 connected neighbours:  0.001 +- 0.002
# Mean cell elongation up to 20 connected neighbours:  0.001 +- 0.001
# Variance nucleus correlation up to 40 connected neighbours:  0.001 +- 0.001
# Mean nucleus sum entropy up to 5 connected neighbours:  0.001 +- 0.001
# Mean cell major axis up to 10 connected neighbours:  0.001 +- 0.001
# Mean nucleus major axis up to 10 connected neighbours:  0.001 +- 0.001
# Cells chain non reciprocal neighbours ratio:  0.001 +- 0.001
# Nucleus information measures correlation 1:  0.001 +- 0.001
# Mean cell major axis up to 5 connected neighbours:  0.001 +- 0.001
# Lateral neighbours alignment:  0.001 +- 0.001
# Cell area:  0.001 +- 0.001
# Variance cytoplasm variance value channel 2 up to 10 connected neighbours:  0.001 +- 0.001
# Mean area ratio up to 20 connected neighbours:  0.001 +- 0.001
# Variance cytoplasm sum average up to 40 connected neighbours:  0.001 +- 0.001
# Variance nucleus information measures correlation 1 up to 20 connected neighbours:  0.001 +- 0.001
# Mean cytoplasm mean value channel 3 up to 40 connected neighbours:  0.001 +- 0.001
# Variance nucleus difference variance up to 20 connected neighbours:  0.001 +- 0.001
# Mean nucleus sum average up to 20 connected neighbours:  0.001 +- 0.001
# Cytoplasm difference entropy:  0.001 +- 0.002
# Variance nucleus mean value channel 2 up to 10 connected neighbours:  0.001 +- 0.001
# Mean cytoplasm mean value channel 2 up to 10 connected neighbours:  0.001 +- 0.001
# Variance nucleus sum variance up to 20 connected neighbours:  0.001 +- 0.001
# Variance cell major axis up to 5 connected neighbours:  0.001 +- 0.002
# Variance cytoplasm difference entropy up to 5 connected neighbours:  0.001 +- 0.001
# Variance cytoplasm information measures correlation 1 up to 5 connected neighbours:  0.001 +- 0.001
# Mean cytoplasm difference variance up to 10 connected neighbours:  0.001 +- 0.001
# Mean cytoplasm sum entropy up to 5 connected neighbours:  0.001 +- 0.001
# Cytoplasm entropy:  0.001 +- 0.001
# Mean cytoplasm mean value channel 1 up to 10 connected neighbours:  0.001 +- 0.001
# Mean nucleus minor axis up to 10 connected neighbours:  0.001 +- 0.001
# Mean cytoplasm difference variance up to 5 connected neighbours:  0.001 +- 0.001
# Mean nucleus entropy up to 20 connected neighbours:  0.001 +- 0.001
# Mean cell elongation up to 10 connected neighbours:  0.001 +- 0.001
# Variance cytoplasm sum average up to 5 connected neighbours:  0.001 +- 0.001
# Variance nucleus mean value channel 1 up to 10 connected neighbours:  0.001 +- 0.001
# Mean cytoplasm sum entropy up to 10 connected neighbours:  0.001 +- 0.001
# Mean nucleus difference entropy up to 20 connected neighbours:  0.001 +- 0.001
# Cell minor Axis:  0.001 +- 0.001
# Variance cytoplasm sum of squares: variance up to 20 connected neighbours:  0.001 +- 0.001
# Variance cell area up to 10 connected neighbours:  0.001 +- 0.001
# Variance cytoplasm mean value channel 2 up to 5 connected neighbours:  0.001 +- 0.001
# Mean nucleus elongation up to 40 connected neighbours:  0.001 +- 0.001
# Mean nucleus mean value channel 1 up to 20 connected neighbours:  0.001 +- 0.001
# Ellipse elongation up to 20 connected neighbours:  0.001 +- 0.001
# Mean cytoplasm sum of squares: variance up to 5 connected neighbours:  0.001 +- 0.001
# Mean nucleus difference variance up to 10 connected neighbours:  0.001 +- 0.001
# Mean nucleus area up to 10 connected neighbours:  0.001 +- 0.001
# Ellipse mean orientation difference up to 40 connected neighbours:  0.001 +- 0.003
# Mean cytoplasm sum variance up to 40 connected neighbours:  0.001 +- 0.001
# Cells number in chain:  0.001 +- 0.001
# Mean cytoplasm contrast up to 10 connected neighbours:  0.001 +- 0.002
# Variance cytoplasm variance value channel 2 up to 40 connected neighbours:  0.0 +- 0.001
# Mean cytoplasm entropy up to 20 connected neighbours:  0.0 +- 0.001
# Mean cytoplasm sum entropy up to 20 connected neighbours:  0.0 +- 0.001
# Mean cytoplasm mean value channel 3 up to 5 connected neighbours:  0.0 +- 0.001
# Mean nucleus area up to 20 connected neighbours:  0.0 +- 0.001
# Variance cytoplasm contrast up to 10 connected neighbours:  0.0 +- 0.001
# Variance cytoplasm mean value channel 3 up to 20 connected neighbours:  0.0 +- 0.001
# Variance cytoplasm mean value channel 2 up to 20 connected neighbours:  0.0 +- 0.001
# Variance cytoplasm variance value channel 1 up to 20 connected neighbours:  0.0 +- 0.001
# Mean cell elongation up to 5 connected neighbours:  0.0 +- 0.001
# Mean cytoplasm mean value channel 2 up to 20 connected neighbours:  0.0 +- 0.001
# Variance orientation difference up to 5 connected neighbours:  0.0 +- 0.001
# Variance nucleus sum entropy up to 5 connected neighbours:  0.0 +- 0.001
# Variance nucleus difference entropy up to 20 connected neighbours:  0.0 +- 0.001
# Mean cell major axis up to 20 connected neighbours:  0.0 +- 0.001
# Mean nucleus information measures correlation 2 up to 5 connected neighbours:  0.0 +- 0.001
# Mean nucleus entropy up to 5 connected neighbours:  0.0 +- 0.001
# Mean nucleus information measures correlation 2 up to 20 connected neighbours:  0.0 +- 0.001
# Variance nucleus mean value channel 2 up to 5 connected neighbours:  0.0 +- 0.001
# Mean nucleus major axis up to 5 connected neighbours:  0.0 +- 0.001
# Variance cytoplasm information measures correlation 2 up to 40 connected neighbours:  0.0 +- 0.001
# Variance distance up to 5 connected neighbours:  0.0 +- 0.001
# Variance nucleus mean value channel 2 up to 40 connected neighbours:  0.0 +- 0.001
# Ellipse minor axis up to 10 connected neighbours:  0.0 +- 0.001
# Mean area ratio up to 10 connected neighbours:  0.0 +- 0.001
# Cell elongation:  0.0 +- 0.001
# Mean nucleus sum average up to 10 connected neighbours:  0.0 +- 0.001
# Mean nucleus entropy up to 10 connected neighbours:  0.0 +- 0.001
# Mean nucleus difference entropy up to 10 connected neighbours:  0.0 +- 0.001
# Variance nucleus correlation up to 10 connected neighbours:  0.0 +- 0.001
# Mean distance up to 5 neighbours:  0.0 +- 0.001
# Variance nucleus information measures correlation 1 up to 40 connected neighbours:  0.0 +- 0.001
# Variance nucleus mean value channel 3 up to 40 connected neighbours:  0.0 +- 0.001
# Variance cytoplasm mean value channel 1 up to 40 connected neighbours:  0.0 +- 0.001
# Mean cytoplasm entropy up to 5 connected neighbours:  0.0 +- 0.001
# Variance cytoplasm information measures correlation 1 up to 20 connected neighbours:  0.0 +- 0.001
# Variance cytoplasm sum of squares: variance up to 5 connected neighbours:  0.0 +- 0.001
# Variance cytoplasm difference variance up to 5 connected neighbours:  0.0 +- 0.001
# Mean cell area up to 40 connected neighbours:  0.0 +- 0.002
# Variance nucleus variance value channel 2 up to 40 connected neighbours:  0.0 +- 0.001
# Direct neighbours variance distance:  0.0 +- 0.001
# Variance cytoplasm sum entropy up to 40 connected neighbours:  0.0 +- 0.001
# Variance nucleus sum of squares: variance up to 20 connected neighbours:  0.0 +- 0.001
# Cytoplasm sum of squares: variance:  0.0 +- 0.001
# Variance cytoplasm angular second moment up to 40 connected neighbours:  0.0 +- 0.001
# Cytoplasm angular second moment:  0.0 +- 0.001
# Variance distance up to 40 connected neighbours:  0.0 +- 0.001
# Variance nucleus sum entropy up to 20 connected neighbours:  0.0 +- 0.001
# Ellipse elongation up to 5 connected neighbours:  0.0 +- 0.001
# Variance cytoplasm variance value channel 3 up to 40 connected neighbours:  0.0 +- 0.001
# Mean cell minor axis up to 40 connected neighbours:  0.0 +- 0.001
# Variance cytoplasm variance value channel 1 up to 40 connected neighbours:  0.0 +- 0.001
# Variance cytoplasm mean value channel 1 up to 20 connected neighbours:  0.0 +- 0.001
# Variance distance up to 40 neighbours:  0.0 +- 0.001
# Variance nucleus mean value channel 3 up to 5 connected neighbours:  0.0 +- 0.001
# Variance nucleus difference variance up to 10 connected neighbours:  0.0 +- 0.001
# Variance cytoplasm correlation up to 5 connected neighbours:  0.0 +- 0.001
# Variance cytoplasm information measures correlation 2 up to 10 connected neighbours:  0.0 +- 0.001
# Variance cytoplasm sum of squares: variance up to 10 connected neighbours:  0.0 +- 0.001
# Mean nucleus information measures correlation 2 up to 10 connected neighbours:  0.0 +- 0.001
# Mean cell minor axis up to 10 connected neighbours:  0.0 +- 0.001
# Variance nucleus sum average up to 5 connected neighbours:  0.0 +- 0.001
# Variance nucleus inverse difference moment up to 5 connected neighbours:  0.0 +- 0.001
# Variance nucleus contrast up to 5 connected neighbours:  0.0 +- 0.001
# Variance cytoplasm difference entropy up to 10 connected neighbours:  0.0 +- 0.001
# Variance nucleus mean value channel 2 up to 20 connected neighbours:  0.0 +- 0.001
# Mean cytoplasm sum variance up to 10 connected neighbours:  0.0 +- 0.001
# Mean cytoplasm information measures correlation 2 up to 5 connected neighbours:  0.0 +- 0.001
# Variance nucleus variance value channel 1 up to 20 connected neighbours:  0.0 +- 0.001
# Nucleus information measures correlation 2:  0.0 +- 0.002
# Mean cell minor axis up to 5 connected neighbours:  0.0 +- 0.001
# Variance cytoplasm mean value channel 3 up to 5 connected neighbours:  0.0 +- 0.001
# Nucleus inverse difference moment:  0.0 +- 0.001
# Variance nucleus variance value channel 3 up to 20 connected neighbours:  0.0 +- 0.0
# Variance cytoplasm information measures correlation 2 up to 5 connected neighbours:  0.0 +- 0.0
# Mean cytoplasm information measures correlation 2 up to 40 connected neighbours:  0.0 +- 0.0
# Variance cytoplasm angular second moment up to 5 connected neighbours:  0.0 +- 0.0
# Variance cytoplasm information measures correlation 2 up to 20 connected neighbours:  0.0 +- 0.0
# Variance cytoplasm sum entropy up to 5 connected neighbours:  0.0 +- 0.0
# Mean cytoplasm mean value channel 3 up to 10 connected neighbours:  0.0 +- 0.0
# Variance nucleus difference entropy up to 10 connected neighbours:  0.0 +- 0.0
# Mean nucleus contrast up to 10 connected neighbours:  0.0 +- 0.0
# Variance orientation difference up to 40 connected neighbours:  0.0 +- 0.0
# Mean nucleus contrast up to 5 connected neighbours:  0.0 +- 0.0
# Variance nucleus mean value channel 1 up to 40 connected neighbours:  0.0 +- 0.0
# Variance nucleus variance value channel 1 up to 40 connected neighbours:  0.0 +- 0.0
# Cells chain tortuosity:  0.0 +- 0.0
# Variance nucleus contrast up to 10 connected neighbours:  0.0 +- 0.0
# Variance nucleus sum variance up to 10 connected neighbours:  0.0 +- 0.0
# Variance nucleus difference variance up to 40 connected neighbours:  0.0 +- 0.0
# Variance cytoplasm inverse difference moment up to 40 connected neighbours:  0.0 +- 0.0
# Variance nucleus entropy up to 40 connected neighbours:  0.0 +- 0.0
# Variance nucleus sum variance up to 40 connected neighbours:  0.0 +- 0.0
# Variance nucleus sum average up to 40 connected neighbours:  0.0 +- 0.0
# Variance nucleus angular second moment up to 10 connected neighbours:  0.0 +- 0.0
# Variance nucleus sum of squares: variance up to 40 connected neighbours:  0.0 +- 0.0
# Nucleus sum of squares: variance:  0.0 +- 0.0
# Variance nucleus contrast up to 40 connected neighbours:  0.0 +- 0.0
# Mean nucleus entropy up to 40 connected neighbours:  0.0 +- 0.0
# Variance nucleus variance value channel 3 up to 40 connected neighbours:  0.0 +- 0.0
# Variance nucleus variance value channel 3 up to 10 connected neighbours:  0.0 +- 0.0
# Variance cytoplasm variance value channel 3 up to 10 connected neighbours:  0.0 +- 0.0
# Variance distance up to 5 neighbours:  0.0 +- 0.0
# Mean cell area up to 5 connected neighbours:  0.0 +- 0.0
# Variance nucleus sum average up to 20 connected neighbours:  0.0 +- 0.0
# Mean nucleus minor axis up to 20 connected neighbours:  0.0 +- 0.0
# Variance nucleus information measures correlation 2 up to 20 connected neighbours:  0.0 +- 0.0
# Mean cell minor axis up to 20 connected neighbours:  0.0 +- 0.0
# Variance nucleus variance value channel 1 up to 10 connected neighbours:  0.0 +- 0.0
# Variance nucleus angular second moment up to 5 connected neighbours:  0.0 +- 0.0
# Mean nucleus difference variance up to 5 connected neighbours:  0.0 +- 0.0
# Variance nucleus inverse difference moment up to 20 connected neighbours:  0.0 +- 0.0
# Mean cytoplasm mean value channel 3 up to 20 connected neighbours:  0.0 +- 0.0
# Variance nucleus contrast up to 20 connected neighbours:  0.0 +- 0.0
# Variance nucleus angular second moment up to 20 connected neighbours:  0.0 +- 0.0
# Variance nucleus variance value channel 2 up to 20 connected neighbours:  0.0 +- 0.0
# Mean nucleus sum of squares: variance up to 5 connected neighbours:  0.0 +- 0.0
# Variance cell elongation up to 10 connected neighbours:  0.0 +- 0.0
# Variance nucleus mean value channel 3 up to 20 connected neighbours:  0.0 +- 0.0
# Variance cytoplasm difference variance up to 20 connected neighbours:  0.0 +- 0.0
# Mean orientation difference up to 10 connected neighbours:  0.0 +- 0.0
# Variance cytoplasm information measures correlation 1 up to 10 connected neighbours:  0.0 +- 0.0
# Ellipse elongation up to 10 connected neighbours:  0.0 +- 0.0
# Variance cytoplasm entropy up to 20 connected neighbours:  0.0 +- 0.0
# Variance cytoplasm sum variance up to 20 connected neighbours:  0.0 +- 0.0
# Variance nucleus sum of squares: variance up to 10 connected neighbours:  0.0 +- 0.0
# Variance nucleus variance value channel 2 up to 10 connected neighbours:  0.0 +- 0.0
# Variance cytoplasm contrast up to 20 connected neighbours:  0.0 +- 0.0
# Variance cytoplasm angular second moment up to 20 connected neighbours:  0.0 +- 0.0
# Mean cytoplasm information measures correlation 2 up to 20 connected neighbours:  0.0 +- 0.0
# Mean cytoplasm information measures correlation 2 up to 10 connected neighbours:  0.0 +- 0.0
# Variance cytoplasm angular second moment up to 10 connected neighbours:  0.0 +- 0.0
# Variance cytoplasm variance value channel 3 up to 20 connected neighbours:  0.0 +- 0.0
# Variance cytoplasm sum average up to 10 connected neighbours:  0.0 +- 0.0
# Variance cytoplasm difference variance up to 10 connected neighbours:  -0.0 +- 0.001
# Variance nucleus entropy up to 20 connected neighbours:  -0.0 +- 0.001
# Variance distance up to 10 neighbours:  -0.0 +- 0.001
# Variance cytoplasm difference entropy up to 20 connected neighbours:  -0.0 +- 0.001
# Mean nucleus mean value channel 2 up to 20 connected neighbours:  -0.0 +- 0.001
# Mean cytoplasm contrast up to 5 connected neighbours:  -0.0 +- 0.001
# Mean cytoplasm angular second moment up to 10 connected neighbours:  -0.0 +- 0.002
# Mean nucleus mean value channel 3 up to 10 connected neighbours:  -0.0 +- 0.002
# Variance nucleus sum entropy up to 10 connected neighbours:  -0.0 +- 0.001
# Variance cytoplasm entropy up to 5 connected neighbours:  -0.0 +- 0.001
# Variance cytoplasm variance value channel 1 up to 10 connected neighbours:  -0.0 +- 0.001
# Nucleus contrast:  -0.0 +- 0.001
# Area ratio:  -0.0 +- 0.003
# Mean orientation difference up to 40 connected neighbours:  -0.0 +- 0.002
# Variance nucleus sum average up to 10 connected neighbours:  -0.0 +- 0.001
# Nucleus area:  -0.0 +- 0.002
# Mean nucleus mean value channel 2 up to 10 connected neighbours:  -0.001 +- 0.001
# Ellipse mean orientation difference up to 5 connected neighbours:  -0.001 +- 0.001
# Cytoplasm sum entropy:  -0.001 +- 0.001
# Variance cytoplasm variance value channel 2 up to 5 connected neighbours:  -0.001 +- 0.001
# Variance cytoplasm variance value channel 3 up to 5 connected neighbours:  -0.001 +- 0.001
# Nucleus variance value channel 2:  -0.002 +- 0.001
